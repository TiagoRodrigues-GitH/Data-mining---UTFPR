# %% [markdown]
# <a href="https://colab.research.google.com/github/TiagoRodrigues-GitH/Data-mining---UTFPR/blob/index.html/Exercicio_EAD_Mestrado_Informatica_Minera%C3%A7%C3%A3o_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <samp>
# - Age: Idade do paciente <br/>
# - Sex: Sexo (M/F) <br/>
# - ChestPainType: Tipo de dor no peito (ATA, NAP, ASY, etc.) <br/>
# - RestingBP: Pressão arterial em repouso <br/>
# - Cholesterol: Nível de colesterol <br/>
# - FastingBS: Nível de açúcar no sangue em jejum (0 ou 1) <br/>
# - RestingECG: Resultados do eletrocardiograma em repouso <br/>
# &nbsp&nbsp -- Normal: Normal <br/>
# &nbsp&nbsp -- ST: Apresentando anormalidade na onda ST-T <br/>
# &nbsp&nbsp -- LVH: Indica hipertrofia ventricular esquerda <br/>
# - MaxHR: Frequência cardíaca máxima atingida <br/>
# - ExerciseAngina: Angina induzida por exercício (Y/N) <br/>
# - Oldpeak: Depressão do segmento ST <br/>
# - ST_Slope: Inclinação do segmento ST <br/>
# - HeartDisease: Diagnóstico de doença cardíaca (0 = não, 1 = sim) <br/>
# </samp>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregar a base de dados
df = pd.read_csv('heart.csv')
display(df.head())

# Verificar os tipos de dados
display(df.info())

# Verificar se há dados faltantes
display(df.isnull().sum())

# Gerar uma estatística descritiva
display(df.describe())
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
# ...

# %%
# Distribuição por idade
sns.histplot(df['Age'], bins=20, kde=True, color='blue')
plt.title('Distribuição por idade')
plt.show()

# %%
# Contagem de pacientes com doença cardiaca
sns.countplot(x='HeartDisease', data=df)
plt.title('Contagem HeartDisease')
plt.show()

# %%
# Boxplot por idade x doença
sns.boxplot(x='HeartDisease', y='Age', data=df)
plt.title('Idade x Doença')
plt.show()

# %%
# Relação MaxHR com Doença
sns.boxplot(x='HeartDisease', y='MaxHR', data=df)
plt.title('MaxHR x Doença')
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
# Contagem por tipo de dores no peito (ChestPainType)
sns.countplot(x='ChestPainType', data=df, order=df['ChestPainType'].value_counts().index)
plt.title('Tipos de Dores no Peito')
plt.show()

# %%
# Avaliar a Distribuição do Colesterol
sns.histplot(df['Cholesterol'], bins = 20, kde=True, color='green')
plt.title('Distribuição do Colesterol')
plt.show()

# %%
# Matriz de Correlação
cm = df.select_dtypes(include=['float64','int64']).corr()
cm
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(cm, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlação')
plt.show()

# %%
# Análises com Groupby
# Média e Mediana da idade com diagnóstico de doença
df.groupby('HeartDisease')['Age'].agg(['median','mean','std','size'])
# Out:
#               median       mean       std  size
# HeartDisease
# 0               51.0  50.551220  9.444915   410
# 1               57.0  55.899606  8.727056   508

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
# Análise de idade x Dores no Peito
df.groupby('ChestPainType')['Age'].agg(['median','mean','std','size'])
# Out:
#                median       mean        std  size
# ChestPainType
# ASY              56.0  54.959677   8.763468   496
# ATA              51.0  49.242775   9.259754   173
# NAP              53.0  53.310345   9.608023   203
# TA               59.0  54.826087  11.449026    46

# %%
# Análise de Colesterol por Dores no Peito
df.groupby('ChestPainType')['Cholesterol'].agg(['median','mean','std','size'])
# Out:
#                median        mean         std  size
# ChestPainType
# ASY             220.5  186.645161  122.058634   496
# ATA             237.0  233.046243   69.266406   173
# NAP             218.0  197.438424  103.869348   203
# TA              229.0  207.065217   83.383292    46

# %%
# Análise de Colesterol por Dores no Peito
df.groupby('Age')['Cholesterol'].agg(['median','mean','std','size'])
# Out:
#      median        mean         std  size
# Age
# 28    132.0  132.000000         NaN     1
# 29    243.0  236.666667   30.005555     3
# 30    237.0  237.000000         NaN     1
# 31    244.5  244.500000   36.062446     2
# 32    225.0  241.200000  189.274140     5
# 33    272.0  272.000000   36.769553     2
# 34    182.0  163.285714   76.421450     7
# 35    192.0  197.454545   83.802582    11
# 36    187.5  190.333333  115.208796     6
# 37    223.0  233.727273   41.219148    11
# 38    182.5  146.500000  126.738050    16
# 39    220.0  239.200000   54.503211    15
# 40    235.0  229.384615  129.476857    13
# 41    236.0  216.500000   82.004242    24
# 42    227.0  212.222222   91.844213    18
# 43    219.0  202.333333  101.799747    24
# 44    226.0  249.578947   82.221460    19
# 45    235.0  229.333333   69.945357    18
# 46    233.5  217.166667   76.881991    24
# 47    243.0  193.421053  105.588465    19
# 48    245.0  228.193548   75.256636    31
# ...

# %%
# Verifcar Colesterol por doença cardiaca
df.groupby('HeartDisease')['Cholesterol'].agg(['median','mean','std','size'])
# Out:
#               median        mean         std  size
# HeartDisease
# 0              227.0  227.121951   74.634659   410
# 1              217.0  175.940945  126.391398   508

# %%
# Verificar a relação de correlção entre MaxHR e doença
df.groupby('HeartDisease')['MaxHR'].agg(['mean','std'])
# Out:
#                     mean        std
# HeartDisease
# 0             148.151220  23.288067
# 1             127.655512  23.386923

# %%
df.groupby(['Sex','HeartDisease','ChestPainType'])['MaxHR'].agg(['mean','std','size'])
# Out:
#                                       mean        std  size
# Sex HeartDisease ChestPainType
# F   0            ASY            140.677419  24.053256    31
#                  ATA            152.785714  18.824273    56
#                  NAP            150.808511  20.286683    47
#                  TA             145.444444  30.091989     9
#     1            ASY            137.897436  20.597387    39
#                  ATA            146.500000  26.652079     4
#                  NAP            130.666667  29.810513     6
#                  TA             143.000000        NaN     1
# M   0            ASY            137.643836  24.517210    73
#                  ATA            151.935484  21.918231    93
#                  NAP            150.547619  24.866102    84
#                  TA             153.176471  19.938140    17
#     1            ASY            124.470255  22.382391   353
#                  ATA            135.700000  27.773710    20
# ...

# %%
df.groupby(['Sex','HeartDisease'])['MaxHR'].agg(['mean','std','size'])
# Out:
#                         mean        std  size
# Sex HeartDisease
# F   0             149.048951  21.597903   143
#     1             137.820000  21.820876    50
# M   0             147.670412  24.170369   267
#     1             126.545852  23.306611   458

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64
